# %% [markdown]
# <a href="https://colab.research.google.com/github/samcain29/module1-codexes-claims-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv')

# %%
df
# Out:
#       BENE_ID|CLM_ID|NCH_NEAR_LINE_REC_IDENT_CD|NCH_CLM_TYPE_CD|CLM_FROM_DT|CLM_THRU_DT|NCH_WKLY_PROC_DT|FI_CLM_PROC_DT|CLAIM_QUERY_CODE|PRVDR_NUM|CLM_FAC_TYPE_CD|CLM_SRVC_CLSFCTN_TYPE_CD|CLM_FREQ_CD|FI_NUM|CLM_MDCR_NON_PMT_RSN_CD|CLM_PMT_AMT|NCH_PRMRY_PYR_CLM_PD_AMT|NCH_PRMRY_PYR_CD|FI_CLM_ACTN_CD|PRVDR_STATE_CD|ORG_NPI_NUM|AT_PHYSN_UPIN|AT_PHYSN_NPI|OP_PHYSN_UPIN|OP_PHYSN_NPI|OT_PHYSN_UPIN|OT_PHYSN_NPI|CLM_MCO_PD_SW|PTNT_DSCHRG_STUS_CD|CLM_PPS_IND_CD|CLM_TOT_CHRG_AMT|CLM_ADMSN_DT|CLM_IP_ADMSN_TYPE_CD|CLM_SRC_IP_ADMSN_CD|NCH_PTNT_STATUS_IND_CD|CLM_PASS_THRU_PER_DIEM_AMT|NCH_BENE_IP_DDCTBL_AMT|NCH_BENE_PTA_COINSRNC_LBLTY_AM|NCH_BENE_BLOOD_DDCTBL_LBLTY_AM|NCH_PROFNL_CMPNT_CHRG_AMT|NCH_IP_NCVRD_CHRG_AMT|NCH_IP_TOT_DDCTN_AMT|CLM_TOT_PPS_CPTL_AMT|CLM_PPS_CPTL_FSP_AMT|CLM_PPS_CPTL_OUTLIER_AMT|CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT|CLM_PPS_CPTL_IME_AMT|CLM_PPS_CPTL_EXCPTN_AMT|CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT|CLM_PPS_CPTL_DRG_WT_NUM|CLM_UTLZTN_DAY_CNT|BENE_TOT_COINSRNC_DAYS_CNT|BENE_LRD_USED_CNT|CLM_
# ...

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep='|')
# Out:
# <ipython-input-17-aafb7dcbe53a>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep='|')

# %%
df
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0     -10000010254618 -10000930037831                          V
# 1     -10000010254653 -10000930038030                          V
# 2     -10000010254653 -10000930038031                          V
# 3     -10000010254656 -10000930038162                          V
# 4     -10000010254656 -10000930038162                          V
# ...               ...             ...                        ...
# 58061 -10000010288008 -10000931485965                          V
# 58062 -10000010288008 -10000931485967                          V
# 58063 -10000010288008 -10000931485969                          V
# 58064 -10000010288008 -10000931485971                          V
# 58065 -10000010288010 -10000931486024                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                   60  25-Mar-2015  25-Mar-2015      27-Mar-2015
# ...

# %%
print(df.columns)
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'CLAIM_QUERY_CODE', 'PRVDR_NUM',
#        ...
#        'PRCDR_DT24', 'ICD_PRCDR_CD25', 'PRCDR_DT25', 'IME_OP_CLM_VAL_AMT',
#        'DSH_OP_CLM_VAL_AMT', 'CLM_UNCOMPD_CARE_PMT_AMT', 'CLM_LINE_NUM',
#        'REV_CNTR', 'HCPCS_CD', 'REV_CNTR_DDCTBL_COINSRNC_CD'],
#       dtype='object', length=197)

# %%
codex_columns = ['PRNCPAL_DGNS_CD',
                 'ICD_DGNS_CD1',
                 'ICD_PRCDR_CD1',
                 'CLM_DRG_CD',
                 'ADMTG_DGNS_CD',
                 'HCPCS_CD',
                 'FST_DGNS_E_CD',
                 'NCH_DRG_OUTLIER_APRVD_PMT_AMT']

# %%
for column in codex_columns:
    print(f"Frequency counts for {column}:")
    value_counts = df[column].value_counts()
    print(value_counts)
    print("\n")
# Out:
# Frequency counts for PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
#           ...
# I25700        1
# I200          1
# E849          1
# A4152         1
# O00109        1
# Name: count, Length: 190, dtype: int64
#
#
# Frequency counts for ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64
#
#
# Frequency counts for ICD_PRCDR_CD1:
# ICD_PRCDR_CD1
# GZ3        16142
# Z741       12421
# BW03ZZZ     3337
# G4730       2134
# F13         2054
#            ...
# 3E03328        1
# 0HBU0ZX        1
# 02YA0Z2        1
# 0SRD0          1
# 0HCV3ZZ        1
# Name: count, Length: 114, dtype: int64
#
#
# Frequency counts for CLM_DRG_CD:
# CLM_DRG_CD
# 951.0    28831
# 950.0     1456
# 949.0     1332
# ...

# %%
print(df.isnull().sum())
# Out:
# BENE_ID                            0
# CLM_ID                             0
# NCH_NEAR_LINE_REC_IDENT_CD         0
# NCH_CLM_TYPE_CD                    0
# CLM_FROM_DT                        0
#                                ...
# CLM_UNCOMPD_CARE_PMT_AMT       58066
# CLM_LINE_NUM                       0
# REV_CNTR                           0
# HCPCS_CD                           0
# REV_CNTR_DDCTBL_COINSRNC_CD     8298
# Length: 197, dtype: int64

# %%
df[codex_column].fillna('Unkown', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c1f190fb4b62> in <cell line: 1>()
# ----> 1 df[codex_column].fillna('Unkown', inplace=True)
#
# NameError: name 'codex_column' is not defined

# %%
for codex_column in codex_columns: # iterate through each column in the list codex_columns
    df[codex_column].fillna('Unknown', inplace=True) # fill NA values with 'Unknown' for the current column
# Out:
# <ipython-input-27-669056661fb0>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df[codex_column].fillna('Unknown', inplace=True) # fill NA values with 'Unknown' for the current column

# %%
for column in codex_columns:
  print(f"Most common codes in {column}:")
  print(df[column].value_counts().head())
# Out:
# Most common codes in PRNCPAL_DGNS_CD:
# PRNCPAL_DGNS_CD
# Z733      11469
# Z608       7216
# T7432X     3314
# Z604       3227
# Z7682      3092
# Name: count, dtype: int64
# Most common codes in ICD_DGNS_CD1:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
# Name: count, dtype: int64
# Most common codes in ICD_PRCDR_CD1:
# ICD_PRCDR_CD1
# GZ3        16142
# Z741       12421
# Unknown     9913
# BW03ZZZ     3337
# G4730       2134
# Name: count, dtype: int64
# Most common codes in CLM_DRG_CD:
# CLM_DRG_CD
# 951.0      28831
# Unknown     3262
# 950.0       1456
# 949.0       1332
# 922.0       1110
# Name: count, dtype: int64
# Most common codes in ADMTG_DGNS_CD:
# ADMTG_DGNS_CD
# Unknown    41938
# Z7682       2881
# T50901A     2541
# Z951        1694
# Z95818      1058
# Name: count, dtype: int64
# Most common codes in HCPCS_CD:
# HCPCS_CD
# 99221    8298
# G0444    7990
# 96156    5080
# 99408    4196
# 99495    3867
# ...

# %%
df.fillna('Unknown', inplace=True)
# Out:
# <ipython-input-30-876f1fdd0c9d>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)
